# %% [markdown]
# <a href="https://colab.research.google.com/github/ayush-kumar-rai/Coding-Raja-Technologies/blob/Fraud-Detection-in-Financial-Transactions/Fraud_Detection_in_Financial_Transactions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('/content/creditcard.csv')
# Out:
# <ipython-input-3-1e88a68a45d2>:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/content/creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3                  V4        V5        V6  \
# 0   0.0 -1.359807 -0.072781  2.536347    1.37815522427443 -0.338321  0.462388
# 1   0.0  1.191857  0.266151  0.166480   0.448154078460911  0.060018 -0.082361
# 2   1.0 -1.358354 -1.340163  1.773209   0.379779593034328 -0.503198  1.800499
# 3   1.0 -0.966272 -0.185226  1.792993  -0.863291275036453 -0.010309  1.247203
# 4   2.0 -1.158233  0.877737  1.548718   0.403033933955121 -0.407193  0.095921
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %%
data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 174418  121099.0  2.116162 -0.020723 -1.561986  0.180724  0.349837 -0.807017
# 174419  121099.0  0.072966  1.004738 -0.452590 -0.530909  0.904533 -0.717924
# 174420  121099.0 -0.469486  1.470284 -0.901081 -1.132544  1.007226 -1.826067
# 174421  121100.0 -0.022203  0.984425 -0.869132 -1.223516  1.204728 -1.256646
# 174422  121100.0  1.998499       NaN       NaN       NaN       NaN       NaN
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 174418  0.198311 -0.333762  0.635628  ...  0.218910  0.831076 -0.091030
# 174419  1.226208 -0.198730 -0.261541  ... -0.300872 -0.735995  0.186777
# 174420  1.709788 -0.501626 -0.051211  ...  0.188097  0.901185 -0.235127
# 174421  1.541838 -0.273428 -0.455793  ...  0.256388  0.871551 -0.304075
# 174422       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174423 entries, 0 to 174422
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    174423 non-null  float64
#  1   V1      174423 non-null  float64
#  2   V2      174422 non-null  float64
#  3   V3      174422 non-null  float64
#  4   V4      174422 non-null  object
#  5   V5      174422 non-null  float64
#  6   V6      174422 non-null  float64
#  7   V7      174422 non-null  float64
#  8   V8      174422 non-null  float64
#  9   V9      174422 non-null  float64
#  10  V10     174422 non-null  float64
#  11  V11     174422 non-null  float64
#  12  V12     174421 non-null  float64
#  13  V13     174421 non-null  float64
#  14  V14     174421 non-null  float64
#  15  V15     174421 non-null  float64
#  16  V16     174421 non-null  float64
#  17  V17     174421 non-null  float64
#  18  V18     174421 non-null  float64
#  19  V19     174421 non-null  float64
# ...

# %%
# checking the number of missing values in each column
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        1
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       2
# V13       2
# V14       2
# V15       2
# V16       2
# V17       2
# V18       2
# V19       2
# V20       2
# V21       2
# V22       2
# V23       2
# V24       2
# V25       2
# V26       2
# V27       2
# V28       2
# Amount    2
# Class     2
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
data['Class'].value_counts()
# Out:
# 0.0    174053
# 1.0       368
# Name: Class, dtype: int64

# %% [markdown]
# # This Dataset is highly unblanced
#
# 0 --> Normal Transaction
#
# 1 --> fraudulent transaction

# %%
# separating the data for analysis
legit = data[data.Class == 0]
fraud = data[data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (174053, 31)
# (368, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    174053.000000
# mean         87.288463
# std         245.301225
# min           0.000000
# 25%           5.490000
# 50%          21.980000
# 75%          76.800000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     368.000000
# mean      112.830924
# std       227.178342
# min         0.000000
# 25%         1.000000
# 50%        13.385000
# 75%       102.125000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
data.groupby('Class').mean()
# Out:
# <ipython-input-14-416fef5f9334>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Class').mean()
#                Time        V1        V2        V3        V5        V6  \
# Class
# 0.0    61262.144485 -0.152547  0.029281  0.501749 -0.164255  0.060224
# 1.0    56036.513587 -6.373036  4.574816 -8.296213 -4.630306 -1.486422
#
#              V7        V8        V9       V10  ...       V20       V21  \
# Class                                          ...
# 0.0   -0.064902  0.029944  0.021137 -0.013355  ...  0.029998 -0.028554
# 1.0   -7.191074  1.042543 -2.868578 -6.621311  ...  0.429563  0.809432
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.080860 -0.022149  0.009074  0.090841  0.012165  0.001731  0.002480
# ...

# %% [markdown]
# # Under-Sampling
#
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions
#
# Number of Fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# # Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3                  V4        V5  \
# 49935    43431.0 -1.892289  2.532521 -1.566072            0.977342 -0.677310
# 123307   76151.0 -0.677851  0.149503  0.829650            0.061595 -0.353598
# 11200    19416.0 -1.261407  0.205666  2.574227    -1.6935761535761  0.038518
# 19305    28627.0  1.390051 -0.372787 -0.218445  -0.563585276492458 -0.733339
# 168690  118261.0 -1.660485  1.152111  2.414436            2.496868  1.549679
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 49935  -0.664391 -0.906711  1.798035 -0.792087  ...  0.143383 -0.050521
# 123307 -0.146398  1.455995 -0.041672 -1.115187  ... -0.043159 -0.592769
# 11200  -0.280722  0.356894 -0.255131  2.577379  ... -0.156465  0.337568
# 19305  -1.366271  0.031286 -0.401321 -1.157988  ... -0.399996 -0.723592
# 168690  0.921755  1.330425 -0.721788 -0.783651  ... -0.600384 -1.233964
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 159900  110617.0 -1.101035 -1.674928 -0.573388  5.617556  0.765556  0.440607
# 165131  115691.0 -1.550273  1.088689 -2.393388  1.008733 -1.087562 -1.104602
# 165568  116067.0  0.949241  1.333519 -4.855402  1.835006 -1.053245 -2.562826
# 169166  118532.0 -5.961457  5.313382 -6.674320  6.028975 -1.387560  0.670638
# 169287  118603.0 -6.677212  5.529299 -7.193275  6.081321 -1.636071  0.500610
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 159900  1.934740 -1.019788 -0.193244  ... -0.412526 -0.208823  0.344833
# 165131 -2.670503  0.147655 -0.978626  ...  0.802316  1.037105  0.095815
# 165568 -2.286986  0.260906 -0.895366  ...  0.306598 -0.854627  0.101177
# 169166 -4.128987 -4.765894 -1.005259  ...  5.556642 -1.501808  1.355172
# 169287 -4.640770 -4.339840 -0.950036  ...  5.563301 -1.608272  0.965322
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    492
# 1.0    368
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
# <ipython-input-20-586b59598b15>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_dataset.groupby('Class').mean()
#                Time        V1        V2        V3        V5        V6  \
# Class
# 0.0    59891.569106 -0.132231 -0.067479  0.506736 -0.072233  0.067706
# 1.0    56036.513587 -6.373036  4.574816 -8.296213 -4.630306 -1.486422
#
#              V7        V8        V9       V10  ...       V20       V21  \
# Class                                          ...
# 0.0   -0.065976 -0.038160  0.063214  0.023091  ...  0.012001 -0.006971
# 1.0   -7.191074  1.042543 -2.868578 -6.621311  ...  0.429563  0.809432
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.067656 -0.067139  0.004984  0.148607  0.009759 -0.016064  0.009274
# ...

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3                  V4        V5  \
# 49935    43431.0 -1.892289  2.532521 -1.566072            0.977342 -0.677310
# 123307   76151.0 -0.677851  0.149503  0.829650            0.061595 -0.353598
# 11200    19416.0 -1.261407  0.205666  2.574227    -1.6935761535761  0.038518
# 19305    28627.0  1.390051 -0.372787 -0.218445  -0.563585276492458 -0.733339
# 168690  118261.0 -1.660485  1.152111  2.414436            2.496868  1.549679
# ...          ...       ...       ...       ...                 ...       ...
# 159900  110617.0 -1.101035 -1.674928 -0.573388            5.617556  0.765556
# 165131  115691.0 -1.550273  1.088689 -2.393388            1.008733 -1.087562
# 165568  116067.0  0.949241  1.333519 -4.855402            1.835006 -1.053245
# 169166  118532.0 -5.961457  5.313382 -6.674320            6.028975 -1.387560
# 169287  118603.0 -6.677212  5.529299 -7.193275            6.081321 -1.636071
#
# ...

# %%
print(Y)
# Out:
# 49935     0.0
# 123307    0.0
# 11200     0.0
# 19305     0.0
# 168690    0.0
#          ...
# 159900    1.0
# 165131    1.0
# 165568    1.0
# 169166    1.0
# 169287    1.0
# Name: Class, Length: 860, dtype: float64

# %% [markdown]
# # Split the data into Training data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (860, 30) (688, 30) (172, 30)

# %% [markdown]
# # Model Training
#
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Model Evaluation
#
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.934593023255814

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.8953488372093024
